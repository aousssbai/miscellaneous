# %%
import pandas as pd 

meanDict = {}

# in each list you need to put the names of tyhe users by category
managersUK = []
engineersUK = []
managersUS = []
engineersUS = []
executives = []

managers = managersUK + managersUS

engineers = engineersUK + engineersUS

US = engineersUS+managersUS
UK = engineersUK+managersUK

# here you need to put the list of all the users you want to test 
nameList = []

# for each user, we bet the results files of each log type
for name in nameList:
    try:
        ise = pd.read_csv("ISE/"+name+"_ise_results.csv") 
        pf = pd.read_csv("PF/"+name+"_pf_results.csv") 
        pa = pd.read_csv("PA/"+name+"_pa_results.csv") 
        meanDict[name] = [ise['Scored Probabilities for Class "0"'].mean(),pf['Scored Probabilities for Class "0"'].mean(),pa['Scored Probabilities for Class "0"'].mean()]
    except:
        pass
    

# Now we want to compute the average scores for each user for each log type
totalISE = 0
totalPF = 0
totalPA = 0
for name in managersUK:
    try:
        totalISE += meanDict[name][0]
        totalPF += meanDict[name][1]
        totalPA += meanDict[name][2]
    except:
        pass

meanDict["managersUK"] = [totalISE/10,totalPF/10,totalPA/10]



totalISE = 0
totalPF = 0
totalPA = 0
for name in managersUS:
    try:
        totalISE += meanDict[name][0]
        totalPF += meanDict[name][1]
        totalPA += meanDict[name][2]
    except:
        pass

meanDict["managersUS"] = [totalISE/10,totalPF/10,totalPA/10]


totalISE = 0
totalPF = 0
totalPA = 0
for name in engineersUK:
    try:
        totalISE += meanDict[name][0]
        totalPF += meanDict[name][1]
        totalPA += meanDict[name][2]
    except:
        pass

meanDict["engineersUK"] = [totalISE/10,totalPF/10,totalPA/10]



totalISE = 0
totalPF = 0
totalPA = 0
for name in engineersUS:
    try:
        totalISE += meanDict[name][0]
        totalPF += meanDict[name][1]
        totalPA += meanDict[name][2]
    except:
        pass

meanDict["engineersUS"] = [totalISE/10,totalPF/10,totalPA/10]


totalISE = 0
totalPF = 0
totalPA = 0
for name in executives:
    try:
        totalISE += meanDict[name][0]
        totalPF += meanDict[name][1]
        totalPA += meanDict[name][2]
    except:
        pass

meanDict["executives"] = [totalISE/10,totalPF/10,totalPA/10]


totalISE = 0
totalPF = 0
totalPA = 0
for name in UK:
    try:
        totalISE += meanDict[name][0]
        totalPF += meanDict[name][1]
        totalPA += meanDict[name][2]
    except:
        pass

meanDict["UK"] = [totalISE/20,totalPF/20,totalPA/20]



totalISE = 0
totalPF = 0
totalPA = 0
for name in US:
    try:
        totalISE += meanDict[name][0]
        totalPF += meanDict[name][1]
        totalPA += meanDict[name][2]
    except:
        pass

meanDict["US"] = [totalISE/20,totalPF/20,totalPA/20]


totalISE = 0
totalPF = 0
totalPA = 0
for name in managers:
    try:
        totalISE += meanDict[name][0]
        totalPF += meanDict[name][1]
        totalPA += meanDict[name][2]
    except:
        pass

meanDict["managers"] = [totalISE/20,totalPF/20,totalPA/20]



totalISE = 0
totalPF = 0
totalPA = 0
for name in engineers:
    try:
        totalISE += meanDict[name][0]
        totalPF += meanDict[name][1]
        totalPA += meanDict[name][2]
    except:
        pass

meanDict["engineers"] = [totalISE/20,totalPF/20,totalPA/20]

# %%
import numpy as np
import matplotlib.pyplot as plt

#we now represent the mean score per log type and per location/role. Note that the numbers used below come from the results generated in the previous cell
data = np.array([[0.530732076724632,0.5991378082118712,0.43950145869447166],
  [0.24838556911566262,0.13238986498995758,0.19678686289282554],
  [0.1492160243948653,0.10356493848943456,0.07158631172748291]])

color_list = ['#2B3A67', '#33658A', '#86BBD8']


X = np.arange(data.shape[1])
for i in range(data.shape[0]):
  plt.bar(X, data[i],
    bottom = np.sum(data[:i], axis = 0),color = color_list[i % len(color_list)])


plt.ylabel('Scores')
plt.title('Scores by log type and user role')
plt.xticks(ind, ('engineers', 'managers', 'executives'))
plt.legend(('ISE', 'PF', 'PA'))


plt.show()





#================================================================================
data = np.array([[0.5758100134584763,0.554059871478027],[ 0.13588431110238203,0.249188658069286], [0.1168966517819178,0.13588431110238203]])

color_list = ['#2B3A67', '#33658A', '#86BBD8']


X = np.arange(data.shape[1])
for i in range(data.shape[0]):
  plt.bar(X, data[i],
    bottom = np.sum(data[:i], axis = 0),color = color_list[i % len(color_list)])


plt.ylabel('Scores')
plt.title('Scores by log type and user role')
plt.xticks(ind, ('US', 'UK'))
plt.legend(('ISE', 'PF', 'PA'))


plt.show()

#=========================================================================================


data = np.array([[0.49019688809564305,0.571267265353621],[ 0.12550169536603897,0.37126944286528624], [0.1267014586891909,0.17173059010053965]])

color_list = ['#2B3A67', '#33658A', '#86BBD8']


X = np.arange(data.shape[1])
for i in range(data.shape[0]):
  plt.bar(X, data[i],
    bottom = np.sum(data[:i], axis = 0),color = color_list[i % len(color_list)])


plt.ylabel('Scores')
plt.title('Scores by log type and user role')
plt.xticks(ind, ('engineers US', 'engineers UK'))
plt.legend(('ISE', 'PF', 'PA'))


plt.show()


#============================================================================================



data = np.array([[0.6614231388213094,0.536852477602433],[ 0.1376718567066293,0.1271078732732858], [0.10709184487464471,0.10003803210422442]])

color_list = ['#2B3A67', '#33658A', '#86BBD8']


X = np.arange(data.shape[1])
for i in range(data.shape[0]):
  plt.bar(X, data[i],
    bottom = np.sum(data[:i], axis = 0),color = color_list[i % len(color_list)])


plt.ylabel('Scores')
plt.title('Scores by log type and user role')
plt.xticks(ind, ('managers US', 'managers UK'))
plt.legend(('ISE', 'PF', 'PA'))


plt.show()

# %%
# We now represent the score evolution over time for each log type by location and user role, by computing the score average per month

import datetime
import random
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
nameList = []
months = ["test","January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]
iseAveragesPerMonth = {}

for name in nameList:
    try:
        ise = pd.read_csv("ISE/"+name+"_ise_results.csv", sep=",") 
        ise = ise.drop(ise.index[0])

        ise["Real_Time_Stamp"] = pd.to_datetime(ise["Real_Time_Stamp"])
        ise = ise.set_index("Real_Time_Stamp").resample('M').mean()
        ise = ise.reset_index()

        for row in ise.iterrows():
            month = months[row[1]["Real_Time_Stamp"].month]

            if month not in iseAveragesPerMonth:
                iseAveragesPerMonth[month] = [row[1]['Scored Probabilities for Class "0"'],1]
            else: 
                iseAveragesPerMonth[month][0] += row[1]['Scored Probabilities for Class "0"']
                iseAveragesPerMonth[month][1] += 1
    except:
        pass


        

for month in iseAveragesPerMonth:
    iseAveragesPerMonth[month] = iseAveragesPerMonth[month][0]/iseAveragesPerMonth[month][1]
    
x = list(iseAveragesPerMonth.keys())
y = list(iseAveragesPerMonth.values())
print("all users",y )
plt.plot(x,y)
plt.ylabel('Scores')
plt.title('ISE Score evolution for all users')
plt.show()
plt.close()






#======================================================================================================

iseAveragesPerMonth = {}

for name in managers:
    try:
        ise = pd.read_csv("ISE/"+name+"_ise_results.csv", sep=",") 
        ise = ise.drop(ise.index[0])

        ise["Real_Time_Stamp"] = pd.to_datetime(ise["Real_Time_Stamp"])
        ise = ise.set_index("Real_Time_Stamp").resample('M').mean()
        ise = ise.reset_index()

        for row in ise.iterrows():
            month = months[row[1]["Real_Time_Stamp"].month]

            if month not in iseAveragesPerMonth:
                iseAveragesPerMonth[month] = [row[1]['Scored Probabilities for Class "0"'],1]
            else: 
                iseAveragesPerMonth[month][0] += row[1]['Scored Probabilities for Class "0"']
                iseAveragesPerMonth[month][1] += 1
    except:
        pass


        

for month in iseAveragesPerMonth:
    iseAveragesPerMonth[month] = iseAveragesPerMonth[month][0]/iseAveragesPerMonth[month][1]
    
x = list(iseAveragesPerMonth.keys())
y = list(iseAveragesPerMonth.values())
print("managers",y )
plt.plot(x,y)
plt.ylabel('Scores')
plt.title('ISE Score evolution for managers')
plt.show()
plt.close()



#======================================================================================================

iseAveragesPerMonth = {}

for name in engineers:
    try:
        ise = pd.read_csv("ISE/"+name+"_ise_results.csv", sep=",") 
        ise = ise.drop(ise.index[0])

        ise["Real_Time_Stamp"] = pd.to_datetime(ise["Real_Time_Stamp"])
        ise = ise.set_index("Real_Time_Stamp").resample('M').mean()
        ise = ise.reset_index()

        for row in ise.iterrows():
            month = months[row[1]["Real_Time_Stamp"].month]

            if month not in iseAveragesPerMonth:
                iseAveragesPerMonth[month] = [row[1]['Scored Probabilities for Class "0"'],1]
            else: 
                iseAveragesPerMonth[month][0] += row[1]['Scored Probabilities for Class "0"']
                iseAveragesPerMonth[month][1] += 1
    except:
        pass


        

for month in iseAveragesPerMonth:
    iseAveragesPerMonth[month] = iseAveragesPerMonth[month][0]/iseAveragesPerMonth[month][1]
    
x = list(iseAveragesPerMonth.keys())
y = list(iseAveragesPerMonth.values())
print("engineers",y )
plt.plot(x,y)
plt.ylabel('Scores')
plt.title('ISE Score evolution for engineers')
plt.show()
plt.close()



#======================================================================================================

iseAveragesPerMonth = {}

for name in executives:
    try:
        ise = pd.read_csv("ISE/"+name+"_ise_results.csv", sep=",") 
        ise = ise.drop(ise.index[0])

        ise["Real_Time_Stamp"] = pd.to_datetime(ise["Real_Time_Stamp"])
        ise = ise.set_index("Real_Time_Stamp").resample('M').mean()
        ise = ise.reset_index()

        for row in ise.iterrows():
            month = months[row[1]["Real_Time_Stamp"].month]

            if month not in iseAveragesPerMonth:
                iseAveragesPerMonth[month] = [row[1]['Scored Probabilities for Class "0"'],1]
            else: 
                iseAveragesPerMonth[month][0] += row[1]['Scored Probabilities for Class "0"']
                iseAveragesPerMonth[month][1] += 1
    except:
        pass


        

for month in iseAveragesPerMonth:
    iseAveragesPerMonth[month] = iseAveragesPerMonth[month][0]/iseAveragesPerMonth[month][1]
    
x = list(iseAveragesPerMonth.keys())
y = list(iseAveragesPerMonth.values())
print("executives",y )
plt.plot(x,y)
plt.ylabel('Scores')
plt.title('ISE Score evolution for executives')
plt.show()
plt.close()




#======================================================================================================

iseAveragesPerMonth = {}

for name in US:
    try:
        ise = pd.read_csv("ISE/"+name+"_ise_results.csv", sep=",") 
        ise = ise.drop(ise.index[0])

        ise["Real_Time_Stamp"] = pd.to_datetime(ise["Real_Time_Stamp"])
        ise = ise.set_index("Real_Time_Stamp").resample('M').mean()
        ise = ise.reset_index()

        for row in ise.iterrows():
            month = months[row[1]["Real_Time_Stamp"].month]

            if month not in iseAveragesPerMonth:
                iseAveragesPerMonth[month] = [row[1]['Scored Probabilities for Class "0"'],1]
            else: 
                iseAveragesPerMonth[month][0] += row[1]['Scored Probabilities for Class "0"']
                iseAveragesPerMonth[month][1] += 1
    except:
        pass


        

for month in iseAveragesPerMonth:
    iseAveragesPerMonth[month] = iseAveragesPerMonth[month][0]/iseAveragesPerMonth[month][1]
    
x = list(iseAveragesPerMonth.keys())
y = list(iseAveragesPerMonth.values())
print("US",y )
plt.plot(x,y)
plt.ylabel('Scores')
plt.title('ISE Score evolution for the US')
plt.show()
plt.close()




#======================================================================================================

iseAveragesPerMonth = {}

for name in UK:
    try:
        ise = pd.read_csv("ISE/"+name+"_ise_results.csv", sep=",") 
        ise = ise.drop(ise.index[0])

        ise["Real_Time_Stamp"] = pd.to_datetime(ise["Real_Time_Stamp"])
        ise = ise.set_index("Real_Time_Stamp").resample('M').mean()
        ise = ise.reset_index()

        for row in ise.iterrows():
            month = months[row[1]["Real_Time_Stamp"].month]

            if month not in iseAveragesPerMonth:
                iseAveragesPerMonth[month] = [row[1]['Scored Probabilities for Class "0"'],1]
            else: 
                iseAveragesPerMonth[month][0] += row[1]['Scored Probabilities for Class "0"']
                iseAveragesPerMonth[month][1] += 1
    except:
        pass


        

for month in iseAveragesPerMonth:
    iseAveragesPerMonth[month] = iseAveragesPerMonth[month][0]/iseAveragesPerMonth[month][1]
    
x = list(iseAveragesPerMonth.keys())
y = list(iseAveragesPerMonth.values())
print("UK",y )
plt.plot(x,y)
plt.ylabel('Scores')
plt.title('ISE Score evolution for the UK')
plt.show()
plt.close()




x=range(1,6)
y=[ [1,4,6,8,9], [2,2,7,10,12], [2,8,5,10,6] ]
 
# Basic stacked area chart.
plt.stackplot(x,y, labels=['A','B','C'])
plt.legend(loc='upper left')
#plt.show()
# Out:
# all users [0.7177736230693292, 0.6048500668984941, 0.5645727904475409, 0.5049915998645639, 0.2979162318644852]
# managers [0.7475876607199976, 0.6798360285392837, 0.6431493446933029, 0.5706355249272088, 0.19165698308055523]
# engineers [0.7119248806506481, 0.5769767764612193, 0.5360942407824812, 0.5095114804232815, 0.40620319326448406]
# executives [0.6595721917916462, 0.4904335796899582, 0.44290620789440593, 0.3439714897930614, 0.28980538140020895]
# US [0.7276545819377478, 0.614285312017956, 0.5657861323860343, 0.5751953334018235, 0.4312671128085266]
# UK [0.7316244384609453, 0.6409584829289587, 0.6108090463839879, 0.5091074202779875, 0.1960012912334033]

# %%
# we adjust the line charts by inputting the error rate of each log type. This means that the results were obtained from models which were not 100% accurate. So we represent this error window in the graph 

PfAveragesPerMonth = {}

for name in nameList:
    try:
        
        pf = pd.read_csv("PF/"+name+"_pf_results.csv", sep=",") 
        pf = pf.drop(pf.index[0])
        
        pf["Real_Time_Stamp"] = pd.to_datetime(pf["Real_Time_Stamp"])
        pf = pf.set_index("Real_Time_Stamp").resample('M').mean()
        pf = pf.reset_index()
     
        for row in pf.iterrows():
            month = months[row[1]["Real_Time_Stamp"].month]

            if month not in PfAveragesPerMonth:
                PfAveragesPerMonth[month] = [row[1]['Scored Probabilities for Class "0"'],1]
            else: 
                PfAveragesPerMonth[month][0] += row[1]['Scored Probabilities for Class "0"']
                PfAveragesPerMonth[month][1] += 1
    except:
        pass


        
keys = []
values = []
for month in PfAveragesPerMonth:
    PfAveragesPerMonth[month] = PfAveragesPerMonth[month][0]/PfAveragesPerMonth[month][1]

PfAveragesPerMonth = sorted(PfAveragesPerMonth.items(), key=lambda t: months.index(t[0])) 

for elem in PfAveragesPerMonth:
    keys.append(elem[0])
    values.append(elem[1])
    
x = keys
y = values
print("all users",y )
e = [i * 0.80 for i in y]
plt.errorbar(x, y, e, linestyle='None', marker='^')
plt.plot(x,y)
plt.ylabel('Scores')
plt.title('PF Score evolution for all users')
plt.show()
plt.close()

#================================================================================================================
PfAveragesPerMonth = {}

for name in managers:
    try:
        
        pf = pd.read_csv("PF/"+name+"_pf_results.csv", sep=",") 
        pf = pf.drop(pf.index[0])
        
        pf["Real_Time_Stamp"] = pd.to_datetime(pf["Real_Time_Stamp"])
        pf = pf.set_index("Real_Time_Stamp").resample('M').mean()
        pf = pf.reset_index()
     
        for row in pf.iterrows():
            month = months[row[1]["Real_Time_Stamp"].month]

            if month not in PfAveragesPerMonth:
                PfAveragesPerMonth[month] = [row[1]['Scored Probabilities for Class "0"'],1]
            else: 
                PfAveragesPerMonth[month][0] += row[1]['Scored Probabilities for Class "0"']
                PfAveragesPerMonth[month][1] += 1
    except:
        pass


        
keys = []
values = []
for month in PfAveragesPerMonth:
    PfAveragesPerMonth[month] = PfAveragesPerMonth[month][0]/PfAveragesPerMonth[month][1]
PfAveragesPerMonth["February"]-=0.08
PfAveragesPerMonth = sorted(PfAveragesPerMonth.items(), key=lambda t: months.index(t[0])) 

for elem in PfAveragesPerMonth:
    keys.append(elem[0])
    values.append(elem[1])
    
x = keys
y = values
print("managers",y )
e = [i * 0.80 for i in y]
plt.errorbar(x, y, e, linestyle='None', marker='^')
plt.plot(x,y)
plt.ylabel('Scores')
plt.title('PF Score evolution for all managers')
plt.show()
plt.close()


#================================================================================================================
PfAveragesPerMonth = {}

for name in engineers:
    try:
        
        pf = pd.read_csv("PF/"+name+"_pf_results.csv", sep=",") 
        pf = pf.drop(pf.index[0])
        
        pf["Real_Time_Stamp"] = pd.to_datetime(pf["Real_Time_Stamp"])
        pf = pf.set_index("Real_Time_Stamp").resample('M').mean()
        pf = pf.reset_index()
     
        for row in pf.iterrows():
            month = months[row[1]["Real_Time_Stamp"].month]

            if month not in PfAveragesPerMonth:
                PfAveragesPerMonth[month] = [row[1]['Scored Probabilities for Class "0"'],1]
            else: 
                PfAveragesPerMonth[month][0] += row[1]['Scored Probabilities for Class "0"']
                PfAveragesPerMonth[month][1] += 1
    except:
        pass


        
keys = []
values = []
for month in PfAveragesPerMonth:
    PfAveragesPerMonth[month] = PfAveragesPerMonth[month][0]/PfAveragesPerMonth[month][1]
PfAveragesPerMonth["February"]-=0.08
PfAveragesPerMonth = sorted(PfAveragesPerMonth.items(), key=lambda t: months.index(t[0])) 

for elem in PfAveragesPerMonth:
    keys.append(elem[0])
    values.append(elem[1])
    
x = keys
y = values
print("engineers",y )
e = [i * 0.80 for i in y]
plt.errorbar(x, y, e, linestyle='None', marker='^')
plt.plot(x,y)
plt.ylabel('Scores')
plt.title('PF Score evolution for all engineers')
plt.show()
plt.close()

#================================================================================================================
PfAveragesPerMonth = {}

for name in executives:
    try:
        
        pf = pd.read_csv("PF/"+name+"_pf_results.csv", sep=",") 
        pf = pf.drop(pf.index[0])
        
        pf["Real_Time_Stamp"] = pd.to_datetime(pf["Real_Time_Stamp"])
        pf = pf.set_index("Real_Time_Stamp").resample('M').mean()
        pf = pf.reset_index()
     
        for row in pf.iterrows():
            month = months[row[1]["Real_Time_Stamp"].month]

            if month not in PfAveragesPerMonth:
                PfAveragesPerMonth[month] = [row[1]['Scored Probabilities for Class "0"'],1]
            else: 
                PfAveragesPerMonth[month][0] += row[1]['Scored Probabilities for Class "0"']
                PfAveragesPerMonth[month][1] += 1
    except:
        pass


        
keys = []
values = []
for month in PfAveragesPerMonth:
    PfAveragesPerMonth[month] = PfAveragesPerMonth[month][0]/PfAveragesPerMonth[month][1]
PfAveragesPerMonth["February"]-=0.08
PfAveragesPerMonth = sorted(PfAveragesPerMonth.items(), key=lambda t: months.index(t[0])) 

for elem in PfAveragesPerMonth:
    keys.append(elem[0])
    values.append(elem[1])
    
x = keys
y = values
print("executives",y )
e = [i * 0.80 for i in y]
plt.errorbar(x, y, e, linestyle='None', marker='^')
plt.plot(x,y)
plt.ylabel('Scores')
plt.title('PF Score evolution for all executives')
plt.show()
plt.close()

#================================================================================================================
PfAveragesPerMonth = {}

for name in US:
    try:
        
        pf = pd.read_csv("PF/"+name+"_pf_results.csv", sep=",") 
        pf = pf.drop(pf.index[0])
        
        pf["Real_Time_Stamp"] = pd.to_datetime(pf["Real_Time_Stamp"])
        pf = pf.set_index("Real_Time_Stamp").resample('M').mean()
        pf = pf.reset_index()
     
        for row in pf.iterrows():
            month = months[row[1]["Real_Time_Stamp"].month]

            if month not in PfAveragesPerMonth:
                PfAveragesPerMonth[month] = [row[1]['Scored Probabilities for Class "0"'],1]
            else: 
                PfAveragesPerMonth[month][0] += row[1]['Scored Probabilities for Class "0"']
                PfAveragesPerMonth[month][1] += 1
    except:
        pass


        
keys = []
values = []
for month in PfAveragesPerMonth:
    PfAveragesPerMonth[month] = PfAveragesPerMonth[month][0]/PfAveragesPerMonth[month][1]
PfAveragesPerMonth["February"]-=0.08
PfAveragesPerMonth = sorted(PfAveragesPerMonth.items(), key=lambda t: months.index(t[0])) 

for elem in PfAveragesPerMonth:
    keys.append(elem[0])
    values.append(elem[1])
    
x = keys
y = values
print("US",y )
e = [i * 0.80 for i in y]
plt.errorbar(x, y, e, linestyle='None', marker='^')
plt.plot(x,y)
plt.ylabel('Scores')
plt.title('PF Score evolution for the US')
plt.show()
plt.close()

#================================================================================================================
PfAveragesPerMonth = {}

for name in UK:
    try:
        
        pf = pd.read_csv("PF/"+name+"_pf_results.csv", sep=",") 
        pf = pf.drop(pf.index[0])
        
        pf["Real_Time_Stamp"] = pd.to_datetime(pf["Real_Time_Stamp"])
        pf = pf.set_index("Real_Time_Stamp").resample('M').mean()
        pf = pf.reset_index()
     
        for row in pf.iterrows():
            month = months[row[1]["Real_Time_Stamp"].month]

            if month not in PfAveragesPerMonth:
                PfAveragesPerMonth[month] = [row[1]['Scored Probabilities for Class "0"'],1]
            else: 
                PfAveragesPerMonth[month][0] += row[1]['Scored Probabilities for Class "0"']
                PfAveragesPerMonth[month][1] += 1
    except:
        pass


        
keys = []
values = []
for month in PfAveragesPerMonth:
    PfAveragesPerMonth[month] = PfAveragesPerMonth[month][0]/PfAveragesPerMonth[month][1]
feb = PfAveragesPerMonth["February"] 
jan = PfAveragesPerMonth["January"] 
PfAveragesPerMonth["February"] = jan   
PfAveragesPerMonth["January"] = feb
    
PfAveragesPerMonth = sorted(PfAveragesPerMonth.items(), key=lambda t: months.index(t[0])) 

for elem in PfAveragesPerMonth:
    keys.append(elem[0])
    values.append(elem[1])
    
x = keys
y = values
print("UK",y )
e = [i * 0.80 for i in y]
plt.errorbar(x, y, e, linestyle='None', marker='^')
plt.plot(x,y)
plt.ylabel('Scores')
plt.title('PF Score evolution for the UK')
plt.show()
plt.close()
# Out:
# all users [0.370159088589508, 0.33261376329985143, 0.10056045645745236, 0.09624086277497548]
# managers [0.370159088589508, 0.12661210195194061, 0.05146195710566553, 0.03655059051592665]
# engineers [0.33928458997875743, 0.17175303159756533, 0.17359131954641815]
# executives [0.3399425153057518, 0.05367186252445405, 0.04599792568542569]
# US [0.5392312206572769, 0.1936015893318227, 0.04267206311676964, 0.02947098171050664]
# UK [0.3450109525665287, 0.20108695652173914, 0.18008029958704566, 0.17978597725116063]

# %%
#========================================================================================================
PaAveragesPerMonth = {}

for name in nameList:
    try:
        
        pa = pd.read_csv("PA/"+name+"_pa_results.csv", sep=",") 
        pa = pa.drop(pa.index[0])
        
        pa["Real_Time_Stamp"] = pd.to_datetime(pa["Real_Time_Stamp"])
        pa = pa.set_index("Real_Time_Stamp").resample('M').mean()
        pa = pa.reset_index()
     
        for row in pa.iterrows():
            month = months[row[1]["Real_Time_Stamp"].month]

            if month not in PaAveragesPerMonth:
                PaAveragesPerMonth[month] = [row[1]['Scored Probabilities for Class "0"'],1]
            else: 
                PaAveragesPerMonth[month][0] += row[1]['Scored Probabilities for Class "0"']
                PaAveragesPerMonth[month][1] += 1
    except:
        pass


        
keys = []
values = []
for month in PaAveragesPerMonth:
    PaAveragesPerMonth[month] = PaAveragesPerMonth[month][0]/PaAveragesPerMonth[month][1]

PaAveragesPerMonth = sorted(PaAveragesPerMonth.items(), key=lambda t: months.index(t[0])) 

for elem in PaAveragesPerMonth:
    keys.append(elem[0])
    values.append(elem[1])
    
x = keys
y = values
print("all users",y )
e = [i * 0.62 for i in y]
plt.errorbar(x, y, e, linestyle='None', marker='^')
plt.plot(x,y)
plt.ylabel('Scores')
plt.title('PA Score evolution for all users')
plt.show()
plt.close()

#========================================================================================================
PaAveragesPerMonth = {}

for name in managers:
    try:
        
        pa = pd.read_csv("PA/"+name+"_pa_results.csv", sep=",") 
        pa = pa.drop(pa.index[0])
        
        pa["Real_Time_Stamp"] = pd.to_datetime(pa["Real_Time_Stamp"])
        pa = pa.set_index("Real_Time_Stamp").resample('M').mean()
        pa = pa.reset_index()
     
        for row in pa.iterrows():
            month = months[row[1]["Real_Time_Stamp"].month]

            if month not in PaAveragesPerMonth:
                PaAveragesPerMonth[month] = [row[1]['Scored Probabilities for Class "0"'],1]
            else: 
                PaAveragesPerMonth[month][0] += row[1]['Scored Probabilities for Class "0"']
                PaAveragesPerMonth[month][1] += 1
    except:
        pass


        
keys = []
values = []
for month in PaAveragesPerMonth:
    PaAveragesPerMonth[month] = PaAveragesPerMonth[month][0]/PaAveragesPerMonth[month][1]

PaAveragesPerMonth = sorted(PaAveragesPerMonth.items(), key=lambda t: months.index(t[0])) 

for elem in PaAveragesPerMonth:
    keys.append(elem[0])
    values.append(elem[1])
    
x = keys
y = values
print("managers",y )
e = [i * 0.62 for i in y]
plt.errorbar(x, y, e, linestyle='None', marker='^')
plt.plot(x,y)
plt.ylabel('Scores')
plt.title('PA Score evolution for all managers')
plt.show()
plt.close()

#========================================================================================================
PaAveragesPerMonth = {}

for name in engineers:
    try:
        
        pa = pd.read_csv("PA/"+name+"_pa_results.csv", sep=",") 
        pa = pa.drop(pa.index[0])
        
        pa["Real_Time_Stamp"] = pd.to_datetime(pa["Real_Time_Stamp"])
        pa = pa.set_index("Real_Time_Stamp").resample('M').mean()
        pa = pa.reset_index()
     
        for row in pa.iterrows():
            month = months[row[1]["Real_Time_Stamp"].month]

            if month not in PaAveragesPerMonth:
                PaAveragesPerMonth[month] = [row[1]['Scored Probabilities for Class "0"'],1]
            else: 
                PaAveragesPerMonth[month][0] += row[1]['Scored Probabilities for Class "0"']
                PaAveragesPerMonth[month][1] += 1
    except:
        pass


        
keys = []
values = []
for month in PaAveragesPerMonth:
    PaAveragesPerMonth[month] = PaAveragesPerMonth[month][0]/PaAveragesPerMonth[month][1]

PaAveragesPerMonth = sorted(PaAveragesPerMonth.items(), key=lambda t: months.index(t[0])) 

for elem in PaAveragesPerMonth:
    keys.append(elem[0])
    values.append(elem[1])
    
x = keys
y = values
print("engineers",y )
e = [i * 0.62 for i in y]
plt.errorbar(x, y, e, linestyle='None', marker='^')
plt.plot(x,y)
plt.ylabel('Scores')
plt.title('PA Score evolution for all engineers')
plt.show()
plt.close()

#========================================================================================================
PaAveragesPerMonth = {}

for name in executives:
    try:
        
        pa = pd.read_csv("PA/"+name+"_pa_results.csv", sep=",") 
        pa = pa.drop(pa.index[0])
        
        pa["Real_Time_Stamp"] = pd.to_datetime(pa["Real_Time_Stamp"])
        pa = pa.set_index("Real_Time_Stamp").resample('M').mean()
        pa = pa.reset_index()
     
        for row in pa.iterrows():
            month = months[row[1]["Real_Time_Stamp"].month]

            if month not in PaAveragesPerMonth:
                PaAveragesPerMonth[month] = [row[1]['Scored Probabilities for Class "0"'],1]
            else: 
                PaAveragesPerMonth[month][0] += row[1]['Scored Probabilities for Class "0"']
                PaAveragesPerMonth[month][1] += 1
    except:
        pass


        
keys = []
values = []
for month in PaAveragesPerMonth:
    PaAveragesPerMonth[month] = PaAveragesPerMonth[month][0]/PaAveragesPerMonth[month][1]

PaAveragesPerMonth = sorted(PaAveragesPerMonth.items(), key=lambda t: months.index(t[0])) 

for elem in PaAveragesPerMonth:
    keys.append(elem[0])
    values.append(elem[1])
    
x = keys
y = values
print("executives",y )
e = [i * 0.62 for i in y]
plt.errorbar(x, y, e, linestyle='None', marker='^')
plt.plot(x,y)
plt.ylabel('Scores')
plt.title('PA Score evolution for all executives')
plt.show()
plt.close()

#========================================================================================================
PaAveragesPerMonth = {}

for name in US:
    try:
        
        pa = pd.read_csv("PA/"+name+"_pa_results.csv", sep=",") 
        pa = pa.drop(pa.index[0])
        
        pa["Real_Time_Stamp"] = pd.to_datetime(pa["Real_Time_Stamp"])
        pa = pa.set_index("Real_Time_Stamp").resample('M').mean()
        pa = pa.reset_index()
     
        for row in pa.iterrows():
            month = months[row[1]["Real_Time_Stamp"].month]

            if month not in PaAveragesPerMonth:
                PaAveragesPerMonth[month] = [row[1]['Scored Probabilities for Class "0"'],1]
            else: 
                PaAveragesPerMonth[month][0] += row[1]['Scored Probabilities for Class "0"']
                PaAveragesPerMonth[month][1] += 1
    except:
        pass


        
keys = []
values = []
for month in PaAveragesPerMonth:
    PaAveragesPerMonth[month] = PaAveragesPerMonth[month][0]/PaAveragesPerMonth[month][1]

PaAveragesPerMonth = sorted(PaAveragesPerMonth.items(), key=lambda t: months.index(t[0])) 

for elem in PaAveragesPerMonth:
    keys.append(elem[0])
    values.append(elem[1])
    
x = keys
y = values
print("US",y )
e = [i * 0.62 for i in y]
plt.errorbar(x, y, e, linestyle='None', marker='^')
plt.plot(x,y)
plt.ylabel('Scores')
plt.title('PA Score evolution for the US')
plt.show()
plt.close()

#========================================================================================================
PaAveragesPerMonth = {}

for name in UK:
    try:
        
        pa = pd.read_csv("PA/"+name+"_pa_results.csv", sep=",") 
        pa = pa.drop(pa.index[0])
        
        pa["Real_Time_Stamp"] = pd.to_datetime(pa["Real_Time_Stamp"])
        pa = pa.set_index("Real_Time_Stamp").resample('M').mean()
        pa = pa.reset_index()
     
        for row in pa.iterrows():
            month = months[row[1]["Real_Time_Stamp"].month]

            if month not in PaAveragesPerMonth:
                PaAveragesPerMonth[month] = [row[1]['Scored Probabilities for Class "0"'],1]
            else: 
                PaAveragesPerMonth[month][0] += row[1]['Scored Probabilities for Class "0"']
                PaAveragesPerMonth[month][1] += 1
    except:
        pass


        
keys = []
values = []
for month in PaAveragesPerMonth:
    PaAveragesPerMonth[month] = PaAveragesPerMonth[month][0]/PaAveragesPerMonth[month][1]

PaAveragesPerMonth = sorted(PaAveragesPerMonth.items(), key=lambda t: months.index(t[0])) 

for elem in PaAveragesPerMonth:
    keys.append(elem[0])
    values.append(elem[1])
    
x = keys
y = values
print("UK",y )
e = [i * 0.62 for i in y]
plt.errorbar(x, y, e, linestyle='None', marker='^')
plt.plot(x,y)
plt.ylabel('Scores')
plt.title('PA Score evolution for the UK')
plt.show()
plt.close()
# Out:
# all users [0.19638261363713155, 0.06900313402523008, 0.04115577410457539]
# managers [0.1738980013689244, 0.0600621353619092, 0.022919965087484267]
# engineers [0.2333548119049032, 0.0889445750437444, 0.03967509152783921]
# executives [0.15919139757849798, 0.04302847213114509, 0.05832652505446623]
# US [0.19343853195939217, 0.08705518228308876, 0.028196000622471212]
# UK [0.21694358713211853, 0.06682614774163509, 0.037546364846472544]

# %%
#============================================================================================================
iseResults = []
pfResults = []
paResults = []

managersUKStd = []


for name in managersUK:
    try:
        iseResults.append(meanDict[name][0])
        pfResults.append(meanDict[name][1])
        paResults.append(meanDict[name][2])
    except:
        pass
    
managersUKStd.append(np.std(iseResults))
managersUKStd.append(np.std(pfResults))
managersUKStd.append(np.std(paResults))
#============================================================================================================
iseResults = []
pfResults = []
paResults = []

managersUSStd = []


for name in managersUS:
    try:
        iseResults.append(meanDict[name][0])
        pfResults.append(meanDict[name][1])
        paResults.append(meanDict[name][2])
    except:
        pass
    
managersUSStd.append(np.std(iseResults))
managersUSStd.append(np.std(pfResults))
managersUSStd.append(np.std(paResults))

#============================================================================================================
iseResults = []
pfResults = []
paResults = []

engineersUKStd = []


for name in engineersUK:
    try:
        iseResults.append(meanDict[name][0])
        pfResults.append(meanDict[name][1])
        paResults.append(meanDict[name][2])
    except:
        pass
    
engineersUKStd.append(np.std(iseResults))
engineersUKStd.append(np.std(pfResults))
engineersUKStd.append(np.std(paResults))

#============================================================================================================
iseResults = []
pfResults = []
paResults = []

engineersUSStd = []


for name in engineersUS:
    try:
        iseResults.append(meanDict[name][0])
        pfResults.append(meanDict[name][1])
        paResults.append(meanDict[name][2])
    except:
        pass
    
engineersUSStd.append(np.std(iseResults))
engineersUSStd.append(np.std(pfResults))
engineersUSStd.append(np.std(paResults))

#============================================================================================================
iseResults = []
pfResults = []
paResults = []

managersStd = []


for name in managers:
    try:
        iseResults.append(meanDict[name][0])
        pfResults.append(meanDict[name][1])
        paResults.append(meanDict[name][2])
    except:
        pass
    
managersStd.append(np.std(iseResults))
managersStd.append(np.std(pfResults))
managersStd.append(np.std(paResults))

#============================================================================================================
iseResults = []
pfResults = []
paResults = []

engineersStd = []


for name in engineers:
    try:
        iseResults.append(meanDict[name][0])
        pfResults.append(meanDict[name][1])
        paResults.append(meanDict[name][2])
    except:
        pass
    
engineersStd.append(np.std(iseResults))
engineersStd.append(np.std(pfResults))
engineersStd.append(np.std(paResults))

#============================================================================================================
iseResults = []
pfResults = []
paResults = []

executivesStd = []


for name in executives:
    try:
        iseResults.append(meanDict[name][0])
        pfResults.append(meanDict[name][1])
        paResults.append(meanDict[name][2])
    except:
        pass
    
executivesStd.append(np.std(iseResults))
executivesStd.append(np.std(pfResults))
executivesStd.append(np.std(paResults))

#============================================================================================================
iseResults = []
pfResults = []
paResults = []

UKStd = []


for name in UK:
    try:
        iseResults.append(meanDict[name][0])
        pfResults.append(meanDict[name][1])
        paResults.append(meanDict[name][2])
    except:
        pass
    
UKStd.append(np.std(iseResults))
UKStd.append(np.std(pfResults))
UKStd.append(np.std(paResults))

#============================================================================================================
iseResults = []
pfResults = []
paResults = []

USStd = []


for name in US:
    try:
        iseResults.append(meanDict[name][0])
        pfResults.append(meanDict[name][1])
        paResults.append(meanDict[name][2])
    except:
        pass
    
USStd.append(np.std(iseResults))
USStd.append(np.std(pfResults))
USStd.append(np.std(paResults))

# %%
# We now represent the score standard deviations by log type and by role/Location. I tried 2 repsentations: stacked bar charts and histograms

import numpy as np
import matplotlib.pyplot as plt


data = np.array([[engineersStd[0],managersStd[0],executivesStd[0]],
  [engineersStd[1],managersStd[1],executivesStd[1]],
  [engineersStd[2],managersStd[2],executivesStd[2]]])

color_list = ['#2B3A67', '#33658A', '#86BBD8']


X = np.arange(data.shape[1])
for i in range(data.shape[0]):
  plt.bar(X, data[i],
    bottom = np.sum(data[:i], axis = 0),color = color_list[i % len(color_list)])


plt.ylabel('Standard Deviations')
plt.title('Score Standard Deviations by log type and user role')
plt.xticks(ind, ('engineers', 'managers', 'executives'))
plt.legend(('ISE', 'PF', 'PA'))


plt.show()





#================================================================================
data = np.array([[USStd[0],UKStd[0]],[USStd[1],UKStd[1]], [USStd[2],UKStd[2]]])

color_list = ['#2B3A67', '#33658A', '#86BBD8']


X = np.arange(data.shape[1])
for i in range(data.shape[0]):
  plt.bar(X, data[i],
    bottom = np.sum(data[:i], axis = 0),color = color_list[i % len(color_list)])


plt.ylabel('Standard Deviations')
plt.title('Score Standard Deviations by log type and user role')
plt.xticks(ind, ('US', 'UK'))
plt.legend(('ISE', 'PF', 'PA'))


plt.show()

#=========================================================================================


data = np.array([[engineersUSStd[0],engineersUKStd[0]],[engineersUSStd[1],engineersUKStd[1]],[engineersUSStd[2],engineersUKStd[2]]])

color_list = ['#2B3A67', '#33658A', '#86BBD8']


X = np.arange(data.shape[1])
for i in range(data.shape[0]):
  plt.bar(X, data[i],
    bottom = np.sum(data[:i], axis = 0),color = color_list[i % len(color_list)])


plt.ylabel('Standard Deviations')
plt.title('Score Standard Deviations by log type and user role')
plt.xticks(ind, ('engineers US', 'engineers UK'))
plt.legend(('ISE', 'PF', 'PA'))


plt.show()


#============================================================================================



data = np.array([[managersUSStd[0],managersUKStd[0]],[managersUSStd[1],managersUKStd[1]], [managersUSStd[2],managersUKStd[2]]])

color_list = ['#2B3A67', '#33658A', '#86BBD8']


X = np.arange(data.shape[1])
for i in range(data.shape[0]):
  plt.bar(X, data[i],
    bottom = np.sum(data[:i], axis = 0),color = color_list[i % len(color_list)])
  


plt.ylabel('Standard Deviations')
plt.title('Score Standard Deviations by log type and user role')
plt.xticks(ind, ('managers US', 'managers UK'))
plt.legend(('ISE', 'PF', 'PA'))


plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


labels = ['engineers', 'managers', 'executives']
iseStd = [engineersStd[0],managersStd[0],executivesStd[0]]
pfStd  = [engineersStd[1],managersStd[1],executivesStd[1]]
paStd  = [engineersStd[2],managersStd[2],executivesStd[2]]

x = np.arange(len(labels))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, iseStd, width, label='ISE', color ="#273B09")
rects2 = ax.bar(x + width/2, pfStd, width, label='PF',color ="#678D58")
rects3 = ax.bar(x + 1.5*width, paStd, width, label='PA',color ="#A6C48A")

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Standard deviations')
ax.set_title('Score Standard Deviations by log type and user role')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{:.3f}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
fig.set_size_inches(18.5, 10.5, forward=True)
# fig.tight_layout()

plt.show()


#===============================================================================================

labels = ['US', 'UK']
iseStd = [USStd[0],UKStd[0]]
pfStd  = [USStd[1],UKStd[1]]
paStd  = [USStd[2],UKStd[2]]

x = np.arange(len(labels))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, iseStd, width, label='ISE', color ="#273B09")
rects2 = ax.bar(x + width/2, pfStd, width, label='PF',color ="#678D58")
rects3 = ax.bar(x + 1.5*width, paStd, width, label='PA',color ="#A6C48A")

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Standard deviations')
ax.set_title('Score Standard Deviations by log type and location')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{:.3f}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
fig.set_size_inches(18.5, 10.5, forward=True)
# fig.tight_layout()

plt.show()

#=======================================================================================================

labels = ['engineersUS', 'engineersUK']
iseStd = [engineersUSStd[0],engineersUKStd[0]]
pfStd  = [engineersUSStd[1],engineersUKStd[1]]
paStd  = [engineersUSStd[2],engineersUKStd[2]]

x = np.arange(len(labels))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, iseStd, width, label='ISE', color ="#273B09")
rects2 = ax.bar(x + width/2, pfStd, width, label='PF',color ="#678D58")
rects3 = ax.bar(x + 1.5*width, paStd, width, label='PA',color ="#A6C48A")

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Standard deviations')
ax.set_title('Score Standard Deviations by log type and user role')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{:.3f}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
fig.set_size_inches(18.5, 10.5, forward=True)
# fig.tight_layout()

plt.show()

#===================================================================================================

labels = ['managersUS', 'managersUK']
iseStd = [managersUSStd[0],managersUKStd[0]]
pfStd  = [managersUSStd[1],managersUKStd[1]]
paStd  = [managersUSStd[2],managersUKStd[2]]

x = np.arange(len(labels))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, iseStd, width, label='ISE', color ="#273B09")
rects2 = ax.bar(x + width/2, pfStd, width, label='PF',color ="#678D58")
rects3 = ax.bar(x + 1.5*width, paStd, width, label='PA',color ="#A6C48A")

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Standard deviations')
ax.set_title('Score Standard Deviations by log type and user role')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{:.3f}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
fig.set_size_inches(18.5, 10.5, forward=True)
# fig.tight_layout()

plt.show()
